# %% [markdown]
# <a href="https://colab.research.google.com/github/Srikanth-c/python-new/blob/module-1/0131_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
input = input()
j = 0
for j in range(0,(len(input))):
  if input[j] == 'a':
    print('01000001',end = ' ')
  if input[j]== 'b':
    print('01000010',end = ' ')
  if input[j]=='c':
    print('01000011',end = ' ')
  if input[j]=='d':
    print('01000100',end = ' ')
  if input[j]=='e':
    print('01000101',end = ' ')
  if input[j]=='f':
    print('01000110',end = ' ')
  if input[j]=='g':
    print('01000111',end = ' ')
  if input[j]=='h':
    print('01001000',end = ' ')
  if input[j]=='i':
    print('01001001',end = ' ')
  if input[j]=='j':
    print('01001010',end = ' ')
  if input[j]=='k':
    print('01001011',end = ' ')
  if input[j]=='l':
    print('01001100',end = ' ')
  if input[j]=='m':
    print('01001101',end = ' ')
  if input[j]=='n':
    print('01001110',end = ' ')
  if input[j]=='o':
    print('01001111',end = ' ')
  if input[j]=='p':
    print('01010000',end = ' ')
  if input[j]=='q':
    print('01010001',end = ' ')
  if input[j]=='r':
    print('01010010',end = ' ')
  if input[j]=='s':
    print('01010011',end = ' ')
  if input[j]=='t':
    print('01010100',end = ' ')
  if input[j]=='u':
    print('01010101',end = ' ')
  if input[j]=='v':
    print('01010110',end = ' ')
  if input[j]=='w':
    print('01010111',end = ' ')
  if input[j]=='x':
    print('01011000',end = ' ')
  if input[j]=='y':
    print('01011001',end = ' ')
  if input[j]=='z':
    print('01011010',end = ' ')
  if input[j] == 'A':
    print('01000001',end = ' ')
  if input[j]== 'B':
    print('01000010',end = ' ')
  if input[j]=='C':
    print('01000011',end = ' ')
  if input[j]=='D':
    print('01000100',end = ' ')
  if input[j]=='E':
    print('01000101',end = ' ')
  if input[j]=='F':
    print('01000110',end = ' ')
  if input[j]=='G':
    print('01000111',end = ' ')
  if input[j]=='H':
    print('01001000',end = ' ')
  if input[j]=='I':
    print('01001001',end = ' ')
  if input[j]=='J':
    print('01001010',end = ' ')
  if input[j]=='K':
    print('01001011',end = ' ')
  if input[j]=='L':
    print('01001100',end = ' ')
  if input[j]=='M':
    print('01001101',end = ' ')
  if input[j]=='N':
    print('01001110',end = ' ')
  if input[j]=='O':
    print('01001111',end = ' ')
  if input[j]=='P':
    print('01010000',end = ' ')
  if input[j]=='Q':
    print('01010001',end = ' ')
  if input[j]=='R':
    print('01010010',end = ' ')
  if input[j]=='S':
    print('01010011',end = ' ')
  if input[j]=='T':
    print('01010100',end = ' ')
  if input[j]=='U':
    print('01010101',end = ' ')
  if input[j]=='V':
    print('01010110',end = ' ')
  if input[j]=='W':
    print('01010111',end = ' ')
  if input[j]=='X':
    print('01011000',end = ' ')
  if input[j]=='Y':
    print('01011001',end = ' ')
  if input[j]=='Z':
    print('01011010',end = ' ')
  if input[j]=='!':
    print('00100001',end = ' ')
  if input[j]=='"':
    print('00100010',end = ' ')
  if input[j]=='#':
    print('00100011',end = ' ')
  if input[j]=='$':
    print('00100100',end = ' ')
  if input[j]=='%':
    print('00100101',end = ' ')
  if input[j]=='&':
    print('00100110',end = ' ')
  if input[j]=="'":
    print('00100111',end = ' ')
  if input[j]=='(':
    print('00101000',end = ' ')
  if input[j]==')':
    print('00101001',end = ' ')
  if input[j]=='*':
    print('00101010',end = ' ')
  if input[j]=='+':
    print('00101011',end = ' ')
  if input[j]==',':
    print('00101100',end = ' ')
  if input[j]=='-':
    print('00101101',end = ' ')
  if input[j]=='.':
    print('00101110',end = ' ')
  if input[j]=='/':
    print('00101111',end = ' ')
  if input[j]=='0':
    print('00110000',end = ' ')
  if input[j]=='1':
    print('00110001',end = ' ')
  if input[j]=='2':
    print('00110010',end = ' ')
  if input[j]=='3':
    print('00110011',end = ' ')
  if input[j]=='4':
    print('00110100',end = ' ')
  if input[j]=='5':
    print('00110101',end = ' ')
  if input[j]=='6':
    print('00110110',end = ' ')
  if input[j]=='7':
    print('00110111',end = ' ')
  if input[j]=='8':
    print('00111000',end = ' ')
  if input[j]=='9':
    print('00111000',end = ' ')
  if input[j]=='?':
    print('00111111',end = ' ')
  if input[j]=='@':
    print('01000000',end = ' ')
  if input[j]==' ':
    print('00100000',end = ' ')
Srikanth
01010000 01010010 01000001 01001010 01010111 01000001 01001100

# %%
## DERIVATION OF AN EQUATION
eq_string = "12x^4+2x^3+6x^2+x^1+1"
print(eq_string)
for i in range(derivation_num):
    print(eq_string)
def derive_term(t):
  list_1 = t.split("x^")
  if list_1[0] == '':
    list_1[0] ='1'
  list_1[0] = int(list_1[0])* int(list_1[1])
  list_1[1] = int(list_1[1]) - 1
  list_1[0] = str(list_1[0])
  list_1[1] = str(list_1[1])
  if list_1[1] == '0':
    eq_string = list_1[0]
  else:
    eq_string = ('x^').join(list_1)
  return eq_string
  from derive_term import derive_term
def derive_equation(eq):
    lst=eq.split('+')
    list_eq= []
    for i in lst:
       if 'x^' in i:
           list_eq.append(derive_term(i))
    return ('+').join(list_eq)
derivation_num = 3
12x^4+2x^3+6x^2+x^1+1
12x^4+2x^3+6x^2+x^1+1
12x^4+2x^3+6x^2+x^1+1
12x^4+2x^3+6x^2+x^1+1
